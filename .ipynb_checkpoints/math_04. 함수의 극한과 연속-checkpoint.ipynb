# %%
from sympy import Limit, S, Symbol

# %%
# x 변수를 생성, x가 0으로 한없이 가까워질 때
# 1/x에 대한 극한값

x = Symbol('x')
Limit(1/x,x,S.Infinity).doit()
# Out:
# 0

# %%
# 우극한 구하기
Limit(1/x,x,0).doit()
# Out:
# oo

# %%
# 좌극한 구하기
Limit(1/x,x,0,dir='-').doit()
# Out:
# -oo
