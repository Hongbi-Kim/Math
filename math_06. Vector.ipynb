# %%
import numpy as np

# %%
# 행벡터
x = np.array([1,2,3])
print(x)
# Out:
# [1 2 3]

# %%
# 크기가 (1,3)인 2차원
np.array([[1,2,3]])
# Out:
# array([[1, 2, 3]])

# %%
# 열벡터
np.array([[1],[2],[3]])
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
from scipy import linalg

# %%
s = np.array([2,3,1])

# %% [markdown]
# - 단위 벡터

# %%
s / linalg.norm(s)
# Out:
# array([0.53452248, 0.80178373, 0.26726124])

# %%
# Norm
x = np.array([1,-3])
v_hat = x / linalg.norm(x)
print(v_hat)
# Out:
# [ 0.31622777 -0.9486833 ]

# %%
# Norm 2
x = np.array([-6,-8])
v_hat2 = x / (x**2).sum()**0.5
print(v_hat2)
# Out:
# [-0.6 -0.8]

# %% [markdown]
# - 영벡터 (zero)

# %%
np.zeros(5) # 실수로 변환
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.zeros(5).shape
# Out:
# (5,)

# %%
s = (2,2)
np.zeros(s)
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %% [markdown]
# - 선형 독립, 선형 종속

# %%
# Rank
# matrix_rank()

x = np.array([[2,7],[5,1]])
np.linalg.matrix_rank(x)
# Out:
# 2

# %%
x1 = np.array([[2,4],[3,6]])
np.linalg.matrix_rank(x1)
# Out:
# 1

# %%
x2 = np.array([[1,2],[3,5]])
np.linalg.matrix_rank(x2)
# Out:
# 2

# %% [markdown]
# - 벡터의 덧셈

# %%
x = [2,3]
y = [3,1]

z = [i+j for i,j in zip(x,y)]
print(z)
# Out:
# [5, 4]

# %% [markdown]
# - 벡터의 뺄셈

# %%
z2 = [i-j for i,j in zip(x,y)]
print(z2)
# Out:
# [-1, 2]

# %% [markdown]
# - 벡터의 곱셈(inner product, outer product)

# %%
x1 = [3,4]
c = 8
z3 = [c*i for i in x1]
print(z3)
# Out:
# [24, 32]

# %% [markdown]
# ## 내적(inner product)

# %%
u = np.array([6,6])
v = np.array([12,0])
np.dot(u,v)
# Out:
# 72

# %%
# zip 함수
list(zip([1,2,3],[4,5,6]))
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %%
list(zip([1,2,3],[4,5,6],[7,8,9]))
# Out:
# [(1, 4, 7), (2, 5, 8), (3, 6, 9)]

# %% [markdown]
# - 벡터의 내적 원리

# %%
import numpy as np

A = np.arange(1*2*3).reshape((1,2,3))
B1 = np.arange(1*2*3).reshape((1,2,3))
B2 = np.arange(1*2*3).reshape((1,3,2))
B3= np.arange(1*2*3).reshape((2,1,3))
B4 = np.arange(1*2*3).reshape((2,3,1))
B5 = np.arange(1*2*3).reshape((3,1,2))
B6 = np.arange(1*2*3).reshape((3,2,1))

# %%
np.dot(A,B1) # 결과는 오류가 맞음.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-bd4c1467bf1a> in <module>
# ----> 1 np.dot(A,B1) # 결과는 오류가 맞음.
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (1,2,3) and (1,2,3) not aligned: 3 (dim 2) != 2 (dim 1)

# %%
np.dot(A,B2)
# Out:
# array([[[[10, 13]],
#
#         [[28, 40]]]])

# %%
np.dot(A,B3) # 결과는 오류가 맞음.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6e4f841571c7> in <module>
# ----> 1 np.dot(A,B3)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (1,2,3) and (2,1,3) not aligned: 3 (dim 2) != 1 (dim 1)

# %%
np.dot(A,B4)
# Out:
# array([[[[ 5],
#          [14]],
#
#         [[14],
#          [50]]]])

# %%
np.dot(A,B5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-60b49c68017f> in <module>
# ----> 1 np.dot(A,B5)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (1,2,3) and (3,1,2) not aligned: 3 (dim 2) != 1 (dim 1)

# %%
np.dot(A,B6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-1ade1b5e0f80> in <module>
# ----> 1 np.dot(A,B6)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (1,2,3) and (3,2,1) not aligned: 3 (dim 2) != 2 (dim 1)

# %%
import numpy as np
u = np.array([3,-6])
v = np.array([-7,9])
uv = np.dot(u,v)
print(uv)
# Out:
# -75

# %% [markdown]
# ## 외적(Outer product)
# - cross() 함수 적용

# %%
# 함수 이용
a = (1,3,5)
b = (2,4,6)

def cross(a,b):
    c = [a[1]*b[2] - a[2]*b[1],
         a[2]*b[0] - a[0]*b[2],
         a[0]*b[1] - a[1]*b[0]]
    return c

# %%
cross(a,b)
# Out:
# [-2, 4, -2]

# %%
# Numpy 를 이용
print(np.cross(a,b))
# Out:
# [-2  4 -2]

# %% [markdown]
# - 직교 벡터

# %%
# 크기가 (1,2)인 2차원 배열

a = np.array([1,2])
print(a)
# Out:
# [1 2]

# %%
np.linalg.norm(a) # a의 길이
# Out:
# 2.23606797749979

# %%
np.linalg.norm(a, ord=1) # L1 Norm 구하기
# Out:
# 3.0

# %%
np.linalg.norm(a, ord=12) # L2 Norm 구하기
# Out:
# 2.000040685551744

# %% [markdown]
# ## 벡터의 거리

# %% [markdown]
# - 유클리디언 거리

# %%
from scipy.spatial import distance

# %%
p1 = (1,2,3)
p2 = (4,5,6)

d = distance.euclidean(p1,p2)
print("Euclidean distance : ", d)
# Out:
# Euclidean distance :  5.196152422706632

# %% [markdown]
# - 멘해튼 거리

# %%
from math import *

# %%
p1 = (1,2,3)
p2 = (4,5,6)

def manhattan_distance(x,y):
    return sum(abs(a-b) for a,b in zip(x,y))

md = manhattan_distance(p1,p2)
print("Menhattan distance : ", md)
# Out:
# Menhattan distance :  9

# %% [markdown]
# - 코사인 유사도

# %%
from numpy import dot
from numpy.linalg import norm
import numpy as np

# %%
def cos_sim(A,B):
    return dot(A,B)/(norm(A)*norm(B))

doc1 = np.array([1,1,1,1,0])
doc2 = np.array([1,0,1,0,1])
doc3 = np.array([2,1,1,1,1])

# %%
print(cos_sim(doc1, doc2)) # 문서 1과 문서 3의 유사도가 가장 높음
print(cos_sim(doc1, doc3))
print(cos_sim(doc2, doc3))
# Out:
# 0.5773502691896258
# 0.8838834764831843
# 0.8164965809277259
